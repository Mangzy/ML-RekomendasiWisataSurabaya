# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import bnlearn as bn

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from pgmpy.models import BayesianNetwork

import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv('datasettlagii.csv')

train['Passenger ID'] = train.index

# Atau, tambahkan kolom "Passenger ID" dengan nilai unik (misalnya, nomor urut)
train['Passenger ID'] = range(1, len(train) + 1)

cols = list(train.columns)
cols = ['Passenger ID'] + [col for col in cols if col != 'Passenger ID']
train = train[cols]

train.set_index('Passenger ID', inplace=True)

# Tampilkan trainFrame
train
# Out:
#                                     Nama Wisata  Escape  Relaxation  Play  \
# Passenger ID
# 1                               Tunjungan Plaza       1           1     1
# 2                               Tunjungan Plaza       1           1     1
# 3                               Tunjungan Plaza       1           0     1
# 4                               Tunjungan Plaza       1           1     1
# 5                               Tunjungan Plaza       1           1     1
# ...                                         ...     ...         ...   ...
# 1346          Balai Pemuda Alun - Alun Surabaya       1           0     1
# 1347          Balai Pemuda Alun - Alun Surabaya       1           1     1
# 1348          Balai Pemuda Alun - Alun Surabaya       1           1     1
# 1349          Balai Pemuda Alun - Alun Surabaya       1           1     1
# 1350          Balai Pemuda Alun - Alun Surabaya       1           1     1
#
# ...

# %%
drop_list = ['Nama Wisata', 'Aktivitas Wisata', 'Tunjungan Plaza',
       'Taman Suroboyo', 'Taman Bungkul', 'Surabaya Convention Center',
       'Stadion Gelora Bung Tomo', 'Pusat Olahraga KONI', 'Pasar Pabean',
       'Pasar Genteng', 'Museum Surabaya Gedung Siola',
       'Museum Pendidikan Surabaya', 'Monumen Kapal Selam',
       'Monumen Tugu Pahlawan', 'Mirota Batik & Handicraft',
       'Masjid Nasional Al Akbar', 'Masjid Cheng Ho', 'Makam Sunan Ampel',
       'Kuliner Pecinan Kembang Jepun', 'Kodam Street Food Surabaya',
       'Kebun Raya Mangrove Gunung Anyar', 'Kebun Binatang Surabaya',
       'Kampung Pecinaan Kapasan Dalam', 'Kampung Lawas Maspati',
       'Jatim International Expo (JIE) Convention Exhibiton',
       'Jalan Tunjungan', 'House of Sampoerna', 'Galaxy Mall Surabaya',
       'Balai Pemuda Alun - Alun Surabaya'],

train_wisata = train.drop(columns=drop_list, axis=27)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 15
#       1 drop_list = ['Nama Wisata', 'Aktivitas Wisata', 'Tunjungan Plaza',
#       2        'Taman Suroboyo', 'Taman Bungkul', 'Surabaya Convention Center',
#       3        'Stadion Gelora Bung Tomo', 'Pusat Olahraga KONI', 'Pasar Pabean',
#    (...)
#      12        'Jalan Tunjungan', 'House of Sampoerna', 'Galaxy Mall Surabaya',
#      13        'Balai Pemuda Alun - Alun Surabaya'],
# ---> 15 train_wisata = train.drop(columns=drop_list, axis=27)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...
