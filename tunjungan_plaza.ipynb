# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import bnlearn as bn

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from pgmpy.models import BayesianNetwork

import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv('tunjungan_plaza.csv')

train['Passenger ID'] = train.index

# Atau, tambahkan kolom "Passenger ID" dengan nilai unik (misalnya, nomor urut)
train['Passenger ID'] = range(1, len(train) + 1)

cols = list(train.columns)
cols = ['Passenger ID'] + [col for col in cols if col != 'Passenger ID']
train = train[cols]

train.set_index('Passenger ID', inplace=True)

# Tampilkan trainFrame
train
# Out:
#                                     Nama Wisata  Escape  Relaxation  Play  \
# Passenger ID
# 1                               Tunjungan Plaza       1           1     1
# 2                               Tunjungan Plaza       1           1     1
# 3                               Tunjungan Plaza       1           0     1
# 4                               Tunjungan Plaza       1           1     1
# 5                               Tunjungan Plaza       1           1     1
# ...                                         ...     ...         ...   ...
# 1346          Balai Pemuda Alun - Alun Surabaya       1           0     1
# 1347          Balai Pemuda Alun - Alun Surabaya       1           1     1
# 1348          Balai Pemuda Alun - Alun Surabaya       1           1     1
# 1349          Balai Pemuda Alun - Alun Surabaya       1           1     1
# 1350          Balai Pemuda Alun - Alun Surabaya       1           1     1
#
#               Strenghthening family bonds  Prestige  Social Interaction  \
# Passenger ID
# 1                                       1         1                   1
# 2                                       1         1                   1
# 3                                       1         1                   1
# 4                                       1         0                   0
# 5                                       1         0                   1
# ...                                   ...       ...                 ...
# 1346                                    1         0                   1
# 1347                                    1         0                   1
# 1348                                    0         1                   1
# 1349                                    1         0                   1
# 1350                                    1         0                   1
#
#               Romance  Educational Opportunity  Self-fulfilment  ...  \
# Passenger ID                                                     ...
# 1                   1                        1                1  ...
# 2                   1                        0                0  ...
# 3                   1                        0                0  ...
# 4                   1                        1                1  ...
# 5                   1                        0                0  ...
# ...               ...                      ...              ...  ...
# 1346                1                        1                0  ...
# 1347                1                        1                1  ...
# 1348                1                        1                1  ...
# 1349                1                        1                1  ...
# 1350                1                        1                0  ...
#
#               Makan Bersama  Berolahraga  Belajar  Berinteraksi dengan satwa  \
# Passenger ID
# 1                         1            1        0                          0
# 2                         1            0        0                          0
# 3                         1            0        1                          0
# 4                         1            0        0                          0
# 5                         1            1        0                          0
# ...                     ...          ...      ...                        ...
# 1346                      0            1        1                          0
# 1347                      0            1        1                          0
# 1348                      1            1        1                          0
# 1349                      1            1        0                          0
# 1350                      1            1        1                          0
#
#               Mengambil Foto Beribadah  Berkemah  Melihat Pemandangan  \
# Passenger ID
# 1                          1         1         0                    0
# 2                          1         1         0                    0
# 3                          1         0         0                    0
# 4                          1         0         0                    0
# 5                          1         0         0                    0
# ...                      ...       ...       ...                  ...
# 1346                       1         0         0                    0
# 1347                       1         0         0                    0
# 1348                       1         0         0                    1
# 1349                       1         0         0                    1
# 1350                       1         0         0                    0
#
#               Berbelanja  Tunjungan Plaza
# Passenger ID
# 1                      1                1
# 2                      1                1
# 3                      1                1
# 4                      1                1
# 5                      1                1
# ...                  ...              ...
# 1346                   0                0
# 1347                   0                0
# 1348                   1                0
# 1349                   1                0
# 1350                   0                0
#
# [1350 rows x 26 columns]

# %%
drop_list = ['Aktivitas Wisata', 'Nama Wisata']

train_wisata = train.drop(columns=drop_list)
train_wisata
# Out:
#               Escape  Relaxation  Play  Strenghthening family bonds  Prestige  \
# Passenger ID
# 1                  1           1     1                            1         1
# 2                  1           1     1                            1         1
# 3                  1           0     1                            1         1
# 4                  1           1     1                            1         0
# 5                  1           1     1                            1         0
# ...              ...         ...   ...                          ...       ...
# 1346               1           0     1                            1         0
# 1347               1           1     1                            1         0
# 1348               1           1     1                            0         1
# 1349               1           1     1                            1         0
# 1350               1           1     1                            1         0
#
#               Social Interaction  Romance  Educational Opportunity  \
# Passenger ID
# 1                              1        1                        1
# 2                              1        1                        0
# 3                              1        1                        0
# 4                              0        1                        1
# 5                              1        1                        0
# ...                          ...      ...                      ...
# 1346                           1        1                        1
# 1347                           1        1                        1
# 1348                           1        1                        1
# 1349                           1        1                        1
# 1350                           1        1                        1
#
#               Self-fulfilment  Wish-fulfiment  ...  Makan Bersama  \
# Passenger ID                                   ...
# 1                           1               0  ...              1
# 2                           0               1  ...              1
# 3                           0               0  ...              1
# 4                           1               0  ...              1
# 5                           0               0  ...              1
# ...                       ...             ...  ...            ...
# 1346                        0               0  ...              0
# 1347                        1               0  ...              0
# 1348                        1               1  ...              1
# 1349                        1               1  ...              1
# 1350                        0               0  ...              1
#
#               Berolahraga  Belajar  Berinteraksi dengan satwa  Mengambil Foto  \
# Passenger ID
# 1                       1        0                          0               1
# 2                       0        0                          0               1
# 3                       0        1                          0               1
# 4                       0        0                          0               1
# 5                       1        0                          0               1
# ...                   ...      ...                        ...             ...
# 1346                    1        1                          0               1
# 1347                    1        1                          0               1
# 1348                    1        1                          0               1
# 1349                    1        0                          0               1
# 1350                    1        1                          0               1
#
#               Beribadah  Berkemah  Melihat Pemandangan  Berbelanja  \
# Passenger ID
# 1                     1         0                    0           1
# 2                     1         0                    0           1
# 3                     0         0                    0           1
# 4                     0         0                    0           1
# 5                     0         0                    0           1
# ...                 ...       ...                  ...         ...
# 1346                  0         0                    0           0
# 1347                  0         0                    0           0
# 1348                  0         0                    1           1
# 1349                  0         0                    1           1
# 1350                  0         0                    0           0
#
#               Tunjungan Plaza
# Passenger ID
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# 5                           1
# ...                       ...
# 1346                        0
# 1347                        0
# 1348                        0
# 1349                        0
# 1350                        0
#
# [1350 rows x 24 columns]

# %%
dfhot_train, dfnum_train = bn.df2onehot(train_wisata)
# Out:
# [df2onehot] >Auto detecting dtypes.
#   0%|          | 0/24 [00:00<?, ?it/s]
# 100%|██████████| 24/24 [00:00<00:00, 140.91it/s]
# [df2onehot] >Set dtypes in dataframe..
# [df2onehot]: 100%|██████████| 24/24 [00:00<00:00, 310.02it/s]
# [df2onehot] >Total onehot features: 48

# %%
dfnum_target = dfnum_train.pop('Tunjungan Plaza')
dfnum_target
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1345    0
# 1346    0
# 1347    0
# 1348    0
# 1349    0
# Name: Tunjungan Plaza, Length: 1350, dtype: int32

# %%
Xtrain, Xval, Ztrain, Zval = train_test_split(dfnum_train, dfnum_target, test_size=0.2, random_state=0)
valid = pd.concat([Xval, Zval], axis='columns')
dfnum = pd.concat([Xtrain, Ztrain], axis='columns')
dfnum
# Out:
#       Escape  Relaxation  Play  Strenghthening family bonds  Prestige  \
# 1118       1           1     0                            1         0
# 642        1           1     1                            1         1
# 687        1           1     0                            1         0
# 322        1           0     1                            1         1
# 326        0           0     1                            1         1
# ...      ...         ...   ...                          ...       ...
# 763        1           1     0                            1         0
# 835        1           1     0                            1         0
# 1216       1           1     0                            1         0
# 559        1           1     1                            1         1
# 684        1           1     1                            1         1
#
#       Social Interaction  Romance  Educational Opportunity  Self-fulfilment  \
# 1118                   1        0                        1                1
# 642                    1        1                        1                1
# 687                    1        0                        1                1
# 322                    0        1                        0                1
# 326                    1        0                        0                0
# ...                  ...      ...                      ...              ...
# 763                    1        0                        1                0
# 835                    1        0                        0                0
# 1216                   1        0                        1                0
# 559                    1        0                        1                1
# 684                    1        1                        1                1
#
#       Wish-fulfiment  ...  Makan Bersama  Berolahraga  Belajar  \
# 1118               1  ...              0            0        1
# 642                1  ...              0            0        1
# 687                1  ...              0            0        0
# 322                1  ...              1            0        0
# 326                1  ...              1            0        0
# ...              ...  ...            ...          ...      ...
# 763                1  ...              0            0        1
# 835                1  ...              1            0        0
# 1216               1  ...              0            0        1
# 559                1  ...              1            1        1
# 684                1  ...              0            0        0
#
#       Berinteraksi dengan satwa  Mengambil Foto  Beribadah  Berkemah  \
# 1118                          0               1          0         0
# 642                           0               1          0         0
# 687                           0               0          1         0
# 322                           0               1          0         0
# 326                           0               1          1         0
# ...                         ...             ...        ...       ...
# 763                           0               0          1         0
# 835                           0               0          0         0
# 1216                          0               1          0         0
# 559                           0               1          1         0
# 684                           0               1          1         0
#
#       Melihat Pemandangan  Berbelanja  Tunjungan Plaza
# 1118                    0           1                0
# 642                     0           0                0
# 687                     0           0                0
# 322                     1           1                0
# 326                     1           1                0
# ...                   ...         ...              ...
# 763                     0           0                0
# 835                     0           1                0
# 1216                    0           0                0
# 559                     1           1                0
# 684                     1           0                0
#
# [1080 rows x 24 columns]

# %%
edges = [
    ('Escape', 'Tunjungan Plaza'),
    ('Relaxation', 'Tunjungan Plaza'),
    ('Play', 'Tunjungan Plaza'),
    ('Strenghthening family bonds', 'Tunjungan Plaza'),
    ('Prestige', 'Tunjungan Plaza'),
    ('Social Interaction', 'Tunjungan Plaza'),
    ('Romance', 'Tunjungan Plaza'),
    ('Educational Opportunity', 'Tunjungan Plaza'),
    ('Self-fulfilment', 'Tunjungan Plaza'),
    ('Wish-fulfiment', 'Tunjungan Plaza'),
    ('Lingkungan', 'Tunjungan Plaza'),
    ('Infrastruktur', 'Tunjungan Plaza'),
    ('Fasilitas', 'Tunjungan Plaza'),
    ('Akomodasi', 'Tunjungan Plaza'),
    ('Tunjungan Plaza', 'Makan Bersama'),
    ('Tunjungan Plaza', 'Berolahraga'),
    ('Tunjungan Plaza', 'Belajar'),
    ('Tunjungan Plaza', 'Berinteraksi dengan satwa'),
    ('Tunjungan Plaza', 'Mengambil Foto'),
    ('Tunjungan Plaza', 'Beribadah'),
    ('Tunjungan Plaza', 'Berkemah'),
    ('Tunjungan Plaza', 'Melihat Pemandangan'),
    ('Tunjungan Plaza', 'Berbelanja')
]

# %%
params_static = {
    'figsize': (15, 10),
    'width': 20,  # Menyesuaikan lebar panah
    'edge_alpha': 0.5,  # Menyesuaikan kejelasan panah
    'arrowstyle': '-|>',  # Gaya panah (ubah sesuai kebutuhan)
    'arrowsize': 20,  # Ukuran panah
    'minscale': 5,
    'maxscale': 15,
    'layout': 'spring_layout',
    'font_size': 14,
    'font_family': 'sans-serif',
    'alpha': 0.8,
    'node_shape': 'o',
    'font_color': '#000000',
    'facecolor': 'white',
    'visible': True
}

# %%
DAG = bn.make_DAG(edges, verbose=0)


bn.print_CPD(DAG)


# Plot
G = bn.plot(DAG, interactive=False, params_static=params_static)


# Parameter learning
model = bn.parameter_learning.fit(DAG, dfnum, verbose=3);
# Out:
# [bnlearn] >No CPDs to print. Hint: Add CPDs as following: <bn.make_DAG(DAG, CPD=[cpd_A, cpd_B, etc])> and use bnlearn.plot(DAG) to make a plot.
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model
# [bnlearn] >Parameter learning> Computing parameters using [bayes]
# [bnlearn] >CPD of Escape:
# +-----------+----------+
# | Escape(0) | 0.299038 |
# +-----------+----------+
# | Escape(1) | 0.700962 |
# +-----------+----------+
# [bnlearn] >CPD of Tunjungan Plaza:
# +-----------------------------+-----+--------------------------------+
# | Akomodasi                   | ... | Akomodasi(1)                   |
# +-----------------------------+-----+--------------------------------+
# | Educational Opportunity     | ... | Educational Opportunity(1)     |
# +-----------------------------+-----+--------------------------------+
# | Escape                      | ... | Escape(1)                      |
# +-----------------------------+-----+--------------------------------+
# | Fasilitas                   | ... | Fasilitas(1)                   |
# +-----------------------------+-----+--------------------------------+
# | Infrastruktur               | ... | Infrastruktur(1)               |
# +-----------------------------+-----+--------------------------------+
# | Lingkungan                  | ... | Lingkungan(1)                  |
# +-----------------------------+-----+--------------------------------+
# | Play                        | ... | Play(1)                        |
# +-----------------------------+-----+--------------------------------+
# | Prestige                    | ... | Prestige(1)                    |
# +-----------------------------+-----+--------------------------------+
# | Relaxation                  | ... | Relaxation(1)                  |
# +-----------------------------+-----+--------------------------------+
# | Romance                     | ... | Romance(1)                     |
# +-----------------------------+-----+--------------------------------+
# | Self-fulfilment             | ... | Self-fulfilment(1)             |
# +-----------------------------+-----+--------------------------------+
# | Social Interaction          | ... | Social Interaction(1)          |
# +-----------------------------+-----+--------------------------------+
# | Strenghthening family bonds | ... | Strenghthening family bonds(1) |
# +-----------------------------+-----+--------------------------------+
# | Wish-fulfiment              | ... | Wish-fulfiment(1)              |
# +-----------------------------+-----+--------------------------------+
# | Tunjungan Plaza(0)          | ... | 0.9901912485766737             |
# +-----------------------------+-----+--------------------------------+
# | Tunjungan Plaza(1)          | ... | 0.009808751423326285           |
# +-----------------------------+-----+--------------------------------+
# [bnlearn] >CPD of Relaxation:
# +---------------+----------+
# | Relaxation(0) | 0.327404 |
# +---------------+----------+
# | Relaxation(1) | 0.672596 |
# +---------------+----------+
# [bnlearn] >CPD of Play:
# +---------+----------+
# | Play(0) | 0.368269 |
# +---------+----------+
# | Play(1) | 0.631731 |
# +---------+----------+
# [bnlearn] >CPD of Strenghthening family bonds:
# +--------------------------------+----------+
# | Strenghthening family bonds(0) | 0.309135 |
# +--------------------------------+----------+
# | Strenghthening family bonds(1) | 0.690865 |
# +--------------------------------+----------+
# [bnlearn] >CPD of Prestige:
# +-------------+----------+
# | Prestige(0) | 0.546154 |
# +-------------+----------+
# | Prestige(1) | 0.453846 |
# +-------------+----------+
# [bnlearn] >CPD of Social Interaction:
# +-----------------------+----------+
# | Social Interaction(0) | 0.307692 |
# +-----------------------+----------+
# | Social Interaction(1) | 0.692308 |
# +-----------------------+----------+
# [bnlearn] >CPD of Romance:
# +------------+----------+
# | Romance(0) | 0.458654 |
# +------------+----------+
# | Romance(1) | 0.541346 |
# +------------+----------+
# [bnlearn] >CPD of Educational Opportunity:
# +----------------------------+----------+
# | Educational Opportunity(0) | 0.357212 |
# +----------------------------+----------+
# | Educational Opportunity(1) | 0.642788 |
# +----------------------------+----------+
# [bnlearn] >CPD of Self-fulfilment:
# +--------------------+----------+
# | Self-fulfilment(0) | 0.465385 |
# +--------------------+----------+
# | Self-fulfilment(1) | 0.534615 |
# +--------------------+----------+
# [bnlearn] >CPD of Wish-fulfiment:
# +-------------------+----------+
# | Wish-fulfiment(0) | 0.451923 |
# +-------------------+----------+
# | Wish-fulfiment(1) | 0.548077 |
# +-------------------+----------+
# [bnlearn] >CPD of Lingkungan:
# +---------------+----------+
# | Lingkungan(0) | 0.275481 |
# +---------------+----------+
# | Lingkungan(1) | 0.724519 |
# +---------------+----------+
# [bnlearn] >CPD of Infrastruktur:
# +------------------+----------+
# | Infrastruktur(0) | 0.297596 |
# +------------------+----------+
# | Infrastruktur(1) | 0.702404 |
# +------------------+----------+
# [bnlearn] >CPD of Fasilitas:
# +--------------+----------+
# | Fasilitas(0) | 0.302404 |
# +--------------+----------+
# | Fasilitas(1) | 0.697596 |
# +--------------+----------+
# [bnlearn] >CPD of Akomodasi:
# +--------------+----------+
# | Akomodasi(0) | 0.491346 |
# +--------------+----------+
# | Akomodasi(1) | 0.508654 |
# +--------------+----------+
# [bnlearn] >CPD of Makan Bersama:
# +------------------+---------------------+---------------------+
# | Tunjungan Plaza  | Tunjungan Plaza(0)  | Tunjungan Plaza(1)  |
# +------------------+---------------------+---------------------+
# | Makan Bersama(0) | 0.5071243523316062  | 0.48880597014925375 |
# +------------------+---------------------+---------------------+
# | Makan Bersama(1) | 0.49287564766839376 | 0.5111940298507462  |
# +------------------+---------------------+---------------------+
# [bnlearn] >CPD of Berolahraga:
# +-----------------+---------------------+---------------------+
# | Tunjungan Plaza | Tunjungan Plaza(0)  | Tunjungan Plaza(1)  |
# +-----------------+---------------------+---------------------+
# | Berolahraga(0)  | 0.6580310880829016  | 0.5205223880597015  |
# +-----------------+---------------------+---------------------+
# | Berolahraga(1)  | 0.34196891191709844 | 0.47947761194029853 |
# +-----------------+---------------------+---------------------+
# [bnlearn] >CPD of Belajar:
# +-----------------+--------------------+--------------------+
# | Tunjungan Plaza | Tunjungan Plaza(0) | Tunjungan Plaza(1) |
# +-----------------+--------------------+--------------------+
# | Belajar(0)      | 0.5479274611398963 | 0.5167910447761194 |
# +-----------------+--------------------+--------------------+
# | Belajar(1)      | 0.4520725388601036 | 0.4832089552238806 |
# +-----------------+--------------------+--------------------+
# [bnlearn] >CPD of Berinteraksi dengan satwa:
# +------------------------------+---------------------+--------------------+
# | Tunjungan Plaza              | Tunjungan Plaza(0)  | Tunjungan Plaza(1) |
# +------------------------------+---------------------+--------------------+
# | Berinteraksi dengan satwa(0) | 0.7992227979274611  | 0.5335820895522388 |
# +------------------------------+---------------------+--------------------+
# | Berinteraksi dengan satwa(1) | 0.20077720207253885 | 0.4664179104477612 |
# +------------------------------+---------------------+--------------------+
# [bnlearn] >CPD of Mengambil Foto:
# +-------------------+---------------------+---------------------+
# | Tunjungan Plaza   | Tunjungan Plaza(0)  | Tunjungan Plaza(1)  |
# +-------------------+---------------------+---------------------+
# | Mengambil Foto(0) | 0.38277202072538863 | 0.48507462686567165 |
# +-------------------+---------------------+---------------------+
# | Mengambil Foto(1) | 0.6172279792746114  | 0.5149253731343284  |
# +-------------------+---------------------+---------------------+
# [bnlearn] >CPD of Beribadah:
# +-----------------+--------------------+--------------------+
# | Tunjungan Plaza | Tunjungan Plaza(0) | Tunjungan Plaza(1) |
# +-----------------+--------------------+--------------------+
# | Beribadah(0)    | 0.7040155440414507 | 0.5298507462686567 |
# +-----------------+--------------------+--------------------+
# | Beribadah(1)    | 0.2959844559585492 | 0.4701492537313433 |
# +-----------------+--------------------+--------------------+
# [bnlearn] >CPD of Berkemah:
# +-----------------+---------------------+--------------------+
# | Tunjungan Plaza | Tunjungan Plaza(0)  | Tunjungan Plaza(1) |
# +-----------------+---------------------+--------------------+
# | Berkemah(0)     | 0.8173575129533679  | 0.5335820895522388 |
# +-----------------+---------------------+--------------------+
# | Berkemah(1)     | 0.18264248704663213 | 0.4664179104477612 |
# +-----------------+---------------------+--------------------+
# [bnlearn] >CPD of Melihat Pemandangan:
# +------------------------+---------------------+---------------------+
# | Tunjungan Plaza        | Tunjungan Plaza(0)  | Tunjungan Plaza(1)  |
# +------------------------+---------------------+---------------------+
# | Melihat Pemandangan(0) | 0.6172279792746114  | 0.5261194029850746  |
# +------------------------+---------------------+---------------------+
# | Melihat Pemandangan(1) | 0.38277202072538863 | 0.47388059701492535 |
# +------------------------+---------------------+---------------------+
# [bnlearn] >CPD of Berbelanja:
# +-----------------+---------------------+--------------------+
# | Tunjungan Plaza | Tunjungan Plaza(0)  | Tunjungan Plaza(1) |
# +-----------------+---------------------+--------------------+
# | Berbelanja(0)   | 0.5867875647668394  | 0.4832089552238806 |
# +-----------------+---------------------+--------------------+
# | Berbelanja(1)   | 0.41321243523316065 | 0.5167910447761194 |
# +-----------------+---------------------+--------------------+
# [bnlearn] >Compute structure scores for model comparison (higher is better).

# %%
def get_acc(model, df, col):
    # Get accuracy score by the model for the validation dataset df with target col
    pred = bn.predict(model, df, variables=[col])
    print(pred)
    acc = accuracy_score(df[col], pred[col])
    print('Accuracy -', acc)
    return acc

# %%
acc1 = get_acc(model, valid, 'Tunjungan Plaza')
# Out:
# [bnlearn]> Remaining columns for inference: 23
#   0%|          | 0/254 [00:00<?, ?it/s]
#   7%|▋         | 17/254 [00:00<00:01, 166.55it/s]
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9696 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0304 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9979 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0021 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9993 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0007 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8158 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1842 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.4671 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.5329 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8148 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1852 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9995 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0005 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8158 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1842 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9990 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0010 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9966 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0034 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9986 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0014 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9995 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0005 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9985 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0015 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9756 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0244 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9989 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0011 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8558 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1442 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9907 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0093 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9994 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0006 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9322 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0678 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8079 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1921 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7447 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2553 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7289 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2711 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9978 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0022 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9956 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0044 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8706 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1294 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8079 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1921 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9968 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0032 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9984 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0016 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9965 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0035 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8646 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1354 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.6880 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.3120 |
# +--------------------+------------------------+
#  20%|██        | 51/254 [00:00<00:01, 160.36it/s]
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8225 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1775 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.4671 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.5329 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9998 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0002 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9977 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0023 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9996 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0004 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9997 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0003 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9882 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0118 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9967 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0033 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8158 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1842 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9980 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0020 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7583 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2417 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9995 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0005 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9928 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0072 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9930 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0070 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9992 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0008 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7583 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2417 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9947 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0053 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9199 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0801 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9951 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0049 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8363 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1637 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9825 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0175 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9950 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0050 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7128 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2872 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9963 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0037 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8329 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1671 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8225 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1775 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9978 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0022 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8033 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1967 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9994 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0006 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.0689 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.9311 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9904 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0096 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9925 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0075 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.6931 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.3069 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9970 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0030 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9984 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0016 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8706 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1294 |
# +--------------------+------------------------+
#  35%|███▌      | 89/254 [00:00<00:00, 174.09it/s]
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9982 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0018 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.1819 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.8181 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9977 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0023 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9995 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0005 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.4054 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.5946 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8646 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1354 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.6494 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.3506 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9962 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0038 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.2390 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.7610 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9992 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0008 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9716 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0284 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9983 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0017 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8646 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1354 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8329 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1671 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7531 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2469 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8329 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1671 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9558 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0442 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8225 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1775 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9899 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0101 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9990 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0010 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8079 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1921 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9891 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0109 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8786 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1214 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9970 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0030 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7035 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2965 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9969 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0031 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.5604 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.4396 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8158 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1842 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7915 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2085 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.1237 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.8763 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9973 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0027 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.5583 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.4417 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.3746 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.6254 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8786 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1214 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.6773 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.3227 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9994 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0006 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9976 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0024 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9959 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0041 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7447 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2553 |
# +--------------------+------------------------+
#  49%|████▉     | 125/254 [00:00<00:00, 163.53it/s]
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8158 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1842 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9985 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0015 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7289 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2711 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9931 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0069 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8786 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1214 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9993 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0007 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8786 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1214 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9934 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0066 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8646 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1354 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9949 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0051 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7447 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2553 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9930 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0070 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8266 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1734 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9961 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0039 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8329 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1671 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9949 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0051 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9980 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0020 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8079 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1921 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.6220 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.3780 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9983 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0017 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7786 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2214 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9934 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0066 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9954 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0046 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9997 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0003 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9989 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0011 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9340 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0660 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9993 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0007 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9861 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0139 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9975 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0025 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9854 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0146 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9430 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0570 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9185 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0815 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8706 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1294 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9997 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0003 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8558 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1442 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9983 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0017 |
# +--------------------+------------------------+
# ...
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7828 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2172 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9916 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0084 |
# +--------------------+------------------------+
#  92%|█████████▏| 234/254 [00:01<00:00, 170.66it/s]
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9904 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0096 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9907 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0093 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9997 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0003 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9911 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0089 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9991 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0009 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9979 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0021 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7447 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2553 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9958 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0042 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7583 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2417 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8148 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1852 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9916 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0084 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9992 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0008 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7142 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2858 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9903 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0097 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9964 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0036 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9891 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0109 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8706 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1294 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.5494 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.4506 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9963 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0037 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9978 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0022 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9891 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0109 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9992 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0008 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9776 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0224 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8225 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1775 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8158 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1842 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.5108 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.4892 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9993 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0007 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8079 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1921 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9931 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0069 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9964 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0036 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8965 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1035 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9966 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0034 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9966 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0034 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9953 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0047 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8148 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1852 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.8646 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.1354 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7447 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2553 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9986 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0014 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9961 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0039 |
# +--------------------+------------------------+
# 100%|██████████| 254/254 [00:01<00:00, 167.57it/s]
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9998 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0002 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.7142 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.2858 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9992 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0008 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.9941 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.0059 |
# +--------------------+------------------------+
# +--------------------+------------------------+
# | Tunjungan Plaza    |   phi(Tunjungan Plaza) |
# +====================+========================+
# | Tunjungan Plaza(0) |                 0.5182 |
# +--------------------+------------------------+
# | Tunjungan Plaza(1) |                 0.4818 |
# +--------------------+------------------------+
#      Tunjungan Plaza         p
# 0                  0  0.969553
# 1                  0  0.997866
# 2                  0  0.999321
# 3                  0  0.815835
# 4                  1  0.532893
# ..               ...       ...
# 265                0  0.999801
# 266                0  0.714184
# 267                0  0.999192
# 268                0  0.994094
# 269                0  0.518204
#
# [270 rows x 2 columns]
# Accuracy - 0.9185185185185185

# %%
pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pred
#
# NameError: name 'pred' is not defined
